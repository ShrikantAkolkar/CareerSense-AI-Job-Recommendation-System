# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/jobposts/data job posts.csv
# /kaggle/input/jobposts/screenshot.jpg

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
jobs= pd.read_csv("/kaggle/input/jobposts/data job posts.csv")

# %%
jobs
# Out:
#                                                  jobpost          date  \
# 0      AMERIA Investment Consulting Company\r\nJOB TI...   Jan 5, 2004
# 1      International Research & Exchanges Board (IREX...   Jan 7, 2004
# 2      Caucasus Environmental NGO Network (CENN)\r\nJ...   Jan 7, 2004
# 3      Manoff Group\r\nJOB TITLE:  BCC Specialist\r\n...   Jan 7, 2004
# 4      Yerevan Brandy Company\r\nJOB TITLE:  Software...  Jan 10, 2004
# ...                                                  ...           ...
# 18996  Technolinguistics NGO\r\n\r\n\r\nTITLE:  Senio...  Dec 28, 2015
# 18997  "Coca-Cola Hellenic Bottling Company Armenia" ...  Dec 30, 2015
# 18998  "Coca-Cola Hellenic Bottling Company Armenia" ...  Dec 30, 2015
# 18999  San Lazzaro   LLC\r\n\r\n\r\nTITLE:  Head of O...  Dec 30, 2015
# 19000  "Kamurj" UCO CJSC\r\n\r\n\r\nTITLE:  Lawyer in...  Dec 30, 2015
#
#                                                    Title  \
# ...

# %%
jobs.shape
# Out:
# (19001, 24)

# %%
jobs.isnull().sum()
# Out:
# jobpost                 0
# date                    0
# Title                  28
# Company                 7
# AnnouncementCode    17793
# Term                11325
# Eligibility         14071
# Audience            18361
# StartDate            9326
# Duration             8203
# Location               32
# JobDescription       3892
# JobRequirment        2522
# RequiredQual          484
# Salary               9379
# ApplicationP           60
# OpeningDate           706
# Deadline               65
# Notes               16790
# AboutC               6531
# Attach              17442
# Year                    0
# Month                   0
# IT                      0
# dtype: int64

# %%
jobs=jobs[["jobpost","date","Title","Company","Location","JobDescription","JobRequirment","RequiredQual","Year","Month","IT"]]

# %%
import re
import string

def normalize_text(text):
    if not isinstance(text, str):
        return ""
    # Replace all \r, \n, \t (single or multiple) with a single space
    cleaned = re.sub(r'[\r\n\t]+', ' ', text)
    # Replace multiple spaces with a single space
    cleaned = text.translate(str.maketrans('', '', string.punctuation))
    cleaned = re.sub(r'\s+', ' ', cleaned).strip()
    return cleaned

# %%
jobs["jobpost"]=jobs["jobpost"].apply(normalize_text)
# Out:
# /tmp/ipykernel_13/4016660049.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobs["jobpost"]=jobs["jobpost"].apply(normalize_text)

# %%
jobs.iloc[1][0]
# Out:
# /tmp/ipykernel_13/4015330112.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   jobs.iloc[1][0]
# ...

# %%
jobs["Company"]=jobs["Company"].apply(normalize_text)
jobs["Title"]=jobs["Title"].apply(normalize_text)
jobs["date"]=jobs["date"].apply(normalize_text)
jobs["Location"]=jobs["Location"].apply(normalize_text)
jobs["JobDescription"]=jobs["JobDescription"].apply(normalize_text)
jobs["JobRequirment"]=jobs["JobRequirment"].apply(normalize_text)
jobs["JobRequirment"]=jobs["JobRequirment"].apply(normalize_text)
jobs["RequiredQual"]=jobs["RequiredQual"].apply(normalize_text)
# Out:
# /tmp/ipykernel_13/4186107597.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobs["Company"]=jobs["Company"].apply(normalize_text)
# /tmp/ipykernel_13/4186107597.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobs["Title"]=jobs["Title"].apply(normalize_text)
# /tmp/ipykernel_13/4186107597.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# Combine selected columns into a new 'tags' column
jobs.loc[:, "tags"] = jobs[columns_to_combine].apply(lambda row: ' '.join(row.values.astype(str)), axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13/1598755905.py in <cell line: 0>()
#       1 # Combine selected columns into a new 'tags' column
# ----> 2 jobs.loc[:, "tags"] = jobs[columns_to_combine].apply(lambda row: ' '.join(row.values.astype(str)), axis=1)
#       3
#
# NameError: name 'columns_to_combine' is not defined

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=5000,stop_words="english")
vectors=cv.fit_transform(jobs["tags"]).toarray()

# %%
vectors

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
def convert(text):
    l=[]
    for i in text.split():
        l.append(ps.stem(i))
    return " ".join(l)

# %%
jobs["tags"]= jobs["tags"].apply(convert)

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity = cosine_similarity(vectors)
similarity[0]

# %%
sorted(list(enumerate(similarity[6])), reverse=True ,key=lambda x:x[1])[1:6]

# %%
similar_indices = [6,3228, 3228, 3297, 18099, 3974]
jobs.loc[similar_indices, ["Title", "Company", "Location", "tags"]]

# %%
jobs.head(10)
